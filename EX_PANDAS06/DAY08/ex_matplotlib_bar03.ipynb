# %% [markdown]
# #### [막대그래프 활용]

# %%
# [1] 모듈 로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# [2] 데이터 준비
species = ('Adelie', 'Chinstrap', 'Gentoo')
sex_counts = {
    'Male': np.array([73, 34, 61]),
    'Female': np.array([73, 34, 58]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence

# %%
# [3] 펭귄 품종 시각화
# - 품종에 따른 성별 비교
fig, ax = plt.subplots()
bottom = np.zeros(3)

for sex, sex_count in sex_counts.items():
    # bottom 매개변수 : 누적
    p = ax.bar(species, sex_count, width, label=sex, bottom=bottom)     
    bottom += sex_count

    # 막대그래프 내에 라벨 추가
    ax.bar_label(p, label_type='center')

ax.set_title('Number of penguins by sex',xlabel='penguins')
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 14
#      11     # 막대그래프 내에 라벨 추가
#      12     ax.bar_label(p, label_type='center')
# ---> 14 ax.set_title('Number of penguins by sex',xlabel='penguins')
#      15 ax.legend()
#      17 plt.show()
#
# File c:\Users\kdp\anaconda3\envs\PY39\lib\site-packages\matplotlib\axes\_axes.py:187, in Axes.set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     185 if fontdict is not None:
#     186     title.update(fontdict)
# --> 187 title._internal_update(kwargs)
#     188 return title
#
# File c:\Users\kdp\anaconda3\envs\PY39\lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File c:\Users\kdp\anaconda3\envs\PY39\lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Text.set() got an unexpected keyword argument 'xlabel'

# %% [markdown]
# - [다중막대그래프]

# %%
# x축 데이터

species = ("Adelie", "Chinstrap", "Gentoo")


# y축 데이터 
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

# 그래프에 나타낼 x축 위치 값, 막대그래프 너비, 다중 막대그래프 간격값

x = np.arange(len(species))  # (0,3,1)
width = 0.25                 # the width of the bars
multiplier = 0               # 막대그래프 간격

# %%
# 품종별 특징 비교 다중그래프 
fig, ax = plt.subplots(layout='constrained')

# 막대그리기
for attribute, measurement in penguin_means.items():
    offset = width * multiplier     # offset => 떨어져있는 간격
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()
